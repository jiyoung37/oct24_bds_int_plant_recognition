# %% [markdown]
# # Import files, libraries, define path and initialize lists

# %%
# !pip install kagglehub
from google.colab import files

import kagglehub

# Download the latest version of the dataset
path = kagglehub.dataset_download("vipoooool/new-plant-diseases-dataset")

print("Path to dataset files:", path)
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (0.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kagglehub) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2024.12.14)
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/vipoooool/new-plant-diseases-dataset?dataset_version_number=2...
# 100%|██████████| 2.70G/2.70G [02:07<00:00, 22.7MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
from PIL import Image
import glob
import os
import shutil
import re
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import EfficientNetV2L
from tensorflow.keras.applications import VGG16
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# Mounted at /content/drive

# %%
# Define the dataset path
root_folder = "/root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2"

data_dir = os.path.join(root_folder, 'new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/')

test_path = os.path.join(root_folder, 'test/test')
train_path = os.path.join(data_dir, 'train')
valid_path = os.path.join(data_dir, 'valid')

# %%
# Initialize lists
image_paths = []
species_labels = []
disease_labels = []
dataset_split = []

# Function to process a dataset directory
def process_directory(base_path, split_name):
    for class_folder in os.listdir(base_path):
        class_folder_path = os.path.join(base_path, class_folder)
        if os.path.isdir(class_folder_path):
            species, disease = class_folder.split('___')
            for image_name in os.listdir(class_folder_path):
                image_paths.append(os.path.join(class_folder_path, image_name))
                species_labels.append(species)
                disease_labels.append(disease)
                dataset_split.append(split_name)

# Process train and valid
process_directory(train_path, 'train')
process_directory(valid_path, 'valid')

# Create DataFrame
df = pd.DataFrame({
    'image_path': image_paths,
    'species': species_labels,
    'disease': disease_labels,
    'split': dataset_split
})

# %% [markdown]
# # Model Training

# %%
import keras
keras.backend.clear_session()

#Define model name
Model_name = 'LLC_VGG16_1Block_unfrozen_v1'

# %%
# Define the image generators for the training and validation set
batch_size = 32
num_classes = 38
img_size = (256, 256)

train_datagen = ImageDataGenerator(rescale=1./255)

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
    valid_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)
# Out:
# Found 70295 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.

# %% [markdown]
# Unfreezing 1 block

# %%
# Import the VGG16 model as a baseline
base_model = VGG16(weights="imagenet", include_top=False, input_shape=(256, 256, 3))

# Print the layers to confirm
for i, layer in enumerate(base_model.layers):
    print(i, layer.name)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# 0 input_layer
# 1 block1_conv1
# 2 block1_conv2
# 3 block1_pool
# 4 block2_conv1
# 5 block2_conv2
# 6 block2_pool
# 7 block3_conv1
# 8 block3_conv2
# 9 block3_conv3
# 10 block3_pool
# 11 block4_conv1
# 12 block4_conv2
# 13 block4_conv3
# 14 block4_pool
# 15 block5_conv1
# 16 block5_conv2
# 17 block5_conv3
# 18 block5_pool

# %%
for layer in base_model.layers[15:]:  # Unfreeze layers starting from index 15
    layer.trainable = True

# %%
# Add custom layers for classification
model_vgg16 = Sequential()
model_vgg16.add(base_model)
model_vgg16.add(GlobalAveragePooling2D())
model_vgg16.add(Dense(1024, activation="relu"))
model_vgg16.add(Dropout(rate=0.2))
model_vgg16.add(Dense(512, activation="relu"))
model_vgg16.add(Dropout(rate=0.2))
model_vgg16.add(Dense(num_classes, activation="softmax"))

# Compile the model
optimizer = Adam(learning_rate = 0.001)
model_vgg16.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# Define callbacks
epoch_checkpoint = ModelCheckpoint(
    'model_epoch_{epoch:02d}.keras',  # Filename to save the model, it will save with the epoch number
    save_weights_only=False,       # Save the entire model (including architecture, optimizer, and weights)
    save_freq='epoch',             # Save the model after every epoch
    verbose=1                      # Print a message when saving the model
)
best_model = ModelCheckpoint(
    f"{Model_name}.keras",
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

callbacks = [
    epoch_checkpoint,
    best_model
]

# %%
# Training the model
model_vgg16.fit(
    train_generator,
    epochs = 50,
    validation_data = validation_generator,
    callbacks = callbacks
    )
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.1305 - loss: 3.1149
# Epoch 1: saving model to model_epoch_01.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.49869, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 246s 98ms/step - accuracy: 0.1306 - loss: 3.1146 - val_accuracy: 0.4987 - val_loss: 1.5422
# Epoch 2/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6014 - loss: 1.2433
# Epoch 2: saving model to model_epoch_02.keras
#
# Epoch 2: val_accuracy improved from 0.49869 to 0.78039, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.6014 - loss: 1.2432 - val_accuracy: 0.7804 - val_loss: 0.6541
# Epoch 3/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7749 - loss: 0.6808
# Epoch 3: saving model to model_epoch_03.keras
#
# Epoch 3: val_accuracy improved from 0.78039 to 0.84635, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 183s 83ms/step - accuracy: 0.7749 - loss: 0.6808 - val_accuracy: 0.8463 - val_loss: 0.4506
# Epoch 4/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8396 - loss: 0.4793
# Epoch 4: saving model to model_epoch_04.keras
#
# Epoch 4: val_accuracy improved from 0.84635 to 0.87952, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 82ms/step - accuracy: 0.8396 - loss: 0.4793 - val_accuracy: 0.8795 - val_loss: 0.3597
# Epoch 5/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8795 - loss: 0.3637
# Epoch 5: saving model to model_epoch_05.keras
#
# Epoch 5: val_accuracy improved from 0.87952 to 0.88476, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 82ms/step - accuracy: 0.8795 - loss: 0.3637 - val_accuracy: 0.8848 - val_loss: 0.3510
# Epoch 6/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8943 - loss: 0.3197
# Epoch 6: saving model to model_epoch_06.keras
#
# Epoch 6: val_accuracy did not improve from 0.88476
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.8943 - loss: 0.3197 - val_accuracy: 0.8446 - val_loss: 0.5052
# Epoch 7/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9091 - loss: 0.2840
# Epoch 7: saving model to model_epoch_07.keras
#
# Epoch 7: val_accuracy improved from 0.88476 to 0.93308, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9091 - loss: 0.2840 - val_accuracy: 0.9331 - val_loss: 0.2034
# Epoch 8/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9275 - loss: 0.2199
# Epoch 8: saving model to model_epoch_08.keras
#
# Epoch 8: val_accuracy did not improve from 0.93308
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9275 - loss: 0.2199 - val_accuracy: 0.9204 - val_loss: 0.2420
# Epoch 9/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9273 - loss: 0.2254
# Epoch 9: saving model to model_epoch_09.keras
#
# Epoch 9: val_accuracy did not improve from 0.93308
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 180s 82ms/step - accuracy: 0.9273 - loss: 0.2254 - val_accuracy: 0.9199 - val_loss: 0.2507
# Epoch 10/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9339 - loss: 0.2044
# Epoch 10: saving model to model_epoch_10.keras
#
# Epoch 10: val_accuracy improved from 0.93308 to 0.93734, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9339 - loss: 0.2044 - val_accuracy: 0.9373 - val_loss: 0.1843
# Epoch 11/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9409 - loss: 0.1838
# Epoch 11: saving model to model_epoch_11.keras
#
# Epoch 11: val_accuracy improved from 0.93734 to 0.93911, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9409 - loss: 0.1838 - val_accuracy: 0.9391 - val_loss: 0.1894
# Epoch 12/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9391 - loss: 0.1935
# Epoch 12: saving model to model_epoch_12.keras
#
# Epoch 12: val_accuracy did not improve from 0.93911
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9391 - loss: 0.1935 - val_accuracy: 0.9326 - val_loss: 0.2057
# Epoch 13/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9480 - loss: 0.1643
# Epoch 13: saving model to model_epoch_13.keras
#
# Epoch 13: val_accuracy did not improve from 0.93911
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 180s 82ms/step - accuracy: 0.9480 - loss: 0.1643 - val_accuracy: 0.9234 - val_loss: 0.2385
# Epoch 14/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9484 - loss: 0.1574
# Epoch 14: saving model to model_epoch_14.keras
#
# Epoch 14: val_accuracy did not improve from 0.93911
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 180s 82ms/step - accuracy: 0.9484 - loss: 0.1574 - val_accuracy: 0.9317 - val_loss: 0.2132
# Epoch 15/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9521 - loss: 0.1460
# Epoch 15: saving model to model_epoch_15.keras
#
# Epoch 15: val_accuracy improved from 0.93911 to 0.94178, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.9521 - loss: 0.1460 - val_accuracy: 0.9418 - val_loss: 0.1831
# Epoch 16/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9544 - loss: 0.1404
# Epoch 16: saving model to model_epoch_16.keras
#
# Epoch 16: val_accuracy did not improve from 0.94178
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 180s 82ms/step - accuracy: 0.9544 - loss: 0.1404 - val_accuracy: 0.9385 - val_loss: 0.1958
# Epoch 17/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9569 - loss: 0.1347
# Epoch 17: saving model to model_epoch_17.keras
#
# Epoch 17: val_accuracy did not improve from 0.94178
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 183s 83ms/step - accuracy: 0.9569 - loss: 0.1347 - val_accuracy: 0.9323 - val_loss: 0.2165
# Epoch 18/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9518 - loss: 0.1556
# Epoch 18: saving model to model_epoch_18.keras
#
# Epoch 18: val_accuracy improved from 0.94178 to 0.95077, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 82ms/step - accuracy: 0.9518 - loss: 0.1556 - val_accuracy: 0.9508 - val_loss: 0.1612
# Epoch 19/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9561 - loss: 0.1474
# Epoch 19: saving model to model_epoch_19.keras
#
# Epoch 19: val_accuracy did not improve from 0.95077
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 180s 82ms/step - accuracy: 0.9561 - loss: 0.1474 - val_accuracy: 0.9332 - val_loss: 0.2173
# Epoch 20/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9501 - loss: 0.1664
# Epoch 20: saving model to model_epoch_20.keras
#
# Epoch 20: val_accuracy did not improve from 0.95077
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 82ms/step - accuracy: 0.9501 - loss: 0.1664 - val_accuracy: 0.8630 - val_loss: 0.4763
# Epoch 21/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9548 - loss: 0.1416
# Epoch 21: saving model to model_epoch_21.keras
#
# Epoch 21: val_accuracy did not improve from 0.95077
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9548 - loss: 0.1416 - val_accuracy: 0.9125 - val_loss: 0.2820
# Epoch 22/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9596 - loss: 0.1307
# Epoch 22: saving model to model_epoch_22.keras
#
# Epoch 22: val_accuracy did not improve from 0.95077
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.9596 - loss: 0.1307 - val_accuracy: 0.9253 - val_loss: 0.2368
# Epoch 23/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9492 - loss: 0.1596
# Epoch 23: saving model to model_epoch_23.keras
#
# Epoch 23: val_accuracy did not improve from 0.95077
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9492 - loss: 0.1596 - val_accuracy: 0.9280 - val_loss: 0.2377
# Epoch 24/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9570 - loss: 0.1423
# Epoch 24: saving model to model_epoch_24.keras
#
# Epoch 24: val_accuracy did not improve from 0.95077
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.9570 - loss: 0.1423 - val_accuracy: 0.9492 - val_loss: 0.1714
# Epoch 25/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9627 - loss: 0.1202
# Epoch 25: saving model to model_epoch_25.keras
#
# Epoch 25: val_accuracy did not improve from 0.95077
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9627 - loss: 0.1202 - val_accuracy: 0.9409 - val_loss: 0.1931
# Epoch 26/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9529 - loss: 0.1646
# Epoch 26: saving model to model_epoch_26.keras
#
# Epoch 26: val_accuracy did not improve from 0.95077
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.9529 - loss: 0.1646 - val_accuracy: 0.9501 - val_loss: 0.1675
# Epoch 27/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9606 - loss: 0.1247
# Epoch 27: saving model to model_epoch_27.keras
#
# Epoch 27: val_accuracy improved from 0.95077 to 0.95607, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.9606 - loss: 0.1247 - val_accuracy: 0.9561 - val_loss: 0.1510
# Epoch 28/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9624 - loss: 0.1215
# Epoch 28: saving model to model_epoch_28.keras
#
# Epoch 28: val_accuracy did not improve from 0.95607
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.9624 - loss: 0.1215 - val_accuracy: 0.9525 - val_loss: 0.1601
# Epoch 29/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9621 - loss: 0.1236
# Epoch 29: saving model to model_epoch_29.keras
#
# Epoch 29: val_accuracy did not improve from 0.95607
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 183s 83ms/step - accuracy: 0.9621 - loss: 0.1236 - val_accuracy: 0.9523 - val_loss: 0.1598
# Epoch 30/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9628 - loss: 0.1207
# Epoch 30: saving model to model_epoch_30.keras
#
# Epoch 30: val_accuracy did not improve from 0.95607
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 183s 83ms/step - accuracy: 0.9628 - loss: 0.1207 - val_accuracy: 0.8889 - val_loss: 0.4671
# Epoch 31/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9506 - loss: 0.1671
# Epoch 31: saving model to model_epoch_31.keras
#
# Epoch 31: val_accuracy improved from 0.95607 to 0.95908, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9506 - loss: 0.1671 - val_accuracy: 0.9591 - val_loss: 0.1401
# Epoch 32/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9622 - loss: 0.1263
# Epoch 32: saving model to model_epoch_32.keras
#
# Epoch 32: val_accuracy did not improve from 0.95908
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 183s 83ms/step - accuracy: 0.9622 - loss: 0.1263 - val_accuracy: 0.9414 - val_loss: 0.1886
# Epoch 33/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9616 - loss: 0.1301
# Epoch 33: saving model to model_epoch_33.keras
#
# Epoch 33: val_accuracy did not improve from 0.95908
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 180s 82ms/step - accuracy: 0.9616 - loss: 0.1301 - val_accuracy: 0.6016 - val_loss: 2.1856
# Epoch 34/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9393 - loss: 0.3290
# Epoch 34: saving model to model_epoch_34.keras
#
# Epoch 34: val_accuracy did not improve from 0.95908
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 180s 82ms/step - accuracy: 0.9393 - loss: 0.3289 - val_accuracy: 0.9575 - val_loss: 0.1494
# Epoch 35/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9647 - loss: 0.1170
# Epoch 35: saving model to model_epoch_35.keras
#
# Epoch 35: val_accuracy did not improve from 0.95908
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.9647 - loss: 0.1170 - val_accuracy: 0.9584 - val_loss: 0.1491
# Epoch 36/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9607 - loss: 0.1270
# Epoch 36: saving model to model_epoch_36.keras
#
# Epoch 36: val_accuracy did not improve from 0.95908
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.9607 - loss: 0.1270 - val_accuracy: 0.9209 - val_loss: 0.2896
# Epoch 37/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9638 - loss: 0.1206
# Epoch 37: saving model to model_epoch_37.keras
#
# Epoch 37: val_accuracy did not improve from 0.95908
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 183s 83ms/step - accuracy: 0.9638 - loss: 0.1206 - val_accuracy: 0.9589 - val_loss: 0.1358
# Epoch 38/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9670 - loss: 0.1107
# Epoch 38: saving model to model_epoch_38.keras
#
# Epoch 38: val_accuracy did not improve from 0.95908
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.9670 - loss: 0.1107 - val_accuracy: 0.9406 - val_loss: 0.1984
# Epoch 39/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9635 - loss: 0.1209
# Epoch 39: saving model to model_epoch_39.keras
#
# Epoch 39: val_accuracy did not improve from 0.95908
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 180s 82ms/step - accuracy: 0.9635 - loss: 0.1209 - val_accuracy: 0.9410 - val_loss: 0.2062
# Epoch 40/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9392 - loss: 0.2213
# Epoch 40: saving model to model_epoch_40.keras
#
# Epoch 40: val_accuracy improved from 0.95908 to 0.95931, saving model to LLC_VGG16_1Block_unfrozen_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.9392 - loss: 0.2213 - val_accuracy: 0.9593 - val_loss: 0.1465
# Epoch 41/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9639 - loss: 0.1189
# Epoch 41: saving model to model_epoch_41.keras
#
# Epoch 41: val_accuracy did not improve from 0.95931
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9639 - loss: 0.1189 - val_accuracy: 0.8780 - val_loss: 0.3857
# Epoch 42/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9503 - loss: 0.1637
# Epoch 42: saving model to model_epoch_42.keras
#
# Epoch 42: val_accuracy did not improve from 0.95931
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 180s 82ms/step - accuracy: 0.9503 - loss: 0.1637 - val_accuracy: 0.9408 - val_loss: 0.2059
# Epoch 43/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9702 - loss: 0.0982
# Epoch 43: saving model to model_epoch_43.keras
#
# Epoch 43: val_accuracy did not improve from 0.95931
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 82ms/step - accuracy: 0.9702 - loss: 0.0982 - val_accuracy: 0.9552 - val_loss: 0.1529
# Epoch 44/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9632 - loss: 0.1246
# Epoch 44: saving model to model_epoch_44.keras
#
# Epoch 44: val_accuracy did not improve from 0.95931
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 179s 81ms/step - accuracy: 0.9632 - loss: 0.1246 - val_accuracy: 0.9395 - val_loss: 0.2128
# Epoch 45/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9675 - loss: 0.1050
# Epoch 45: saving model to model_epoch_45.keras
#
# Epoch 45: val_accuracy did not improve from 0.95931
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9675 - loss: 0.1050 - val_accuracy: 0.9566 - val_loss: 0.1504
# Epoch 46/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9293 - loss: 0.2625
# Epoch 46: saving model to model_epoch_46.keras
#
# Epoch 46: val_accuracy did not improve from 0.95931
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 181s 82ms/step - accuracy: 0.9292 - loss: 0.2629 - val_accuracy: 0.0276 - val_loss: 3.6400
# Epoch 47/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0267 - loss: 3.6456
# Epoch 47: saving model to model_epoch_47.keras
#
# Epoch 47: val_accuracy did not improve from 0.95931
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 180s 82ms/step - accuracy: 0.0267 - loss: 3.6456 - val_accuracy: 0.0287 - val_loss: 3.6361
# Epoch 48/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0284 - loss: 3.6481
# Epoch 48: saving model to model_epoch_48.keras
#
# Epoch 48: val_accuracy did not improve from 0.95931
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 183s 83ms/step - accuracy: 0.0284 - loss: 3.6481 - val_accuracy: 0.0283 - val_loss: 3.6360
# Epoch 49/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0270 - loss: 3.6458
# Epoch 49: saving model to model_epoch_49.keras
#
# Epoch 49: val_accuracy did not improve from 0.95931
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 183s 83ms/step - accuracy: 0.0270 - loss: 3.6458 - val_accuracy: 0.0287 - val_loss: 3.6360
# Epoch 50/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0277 - loss: 3.6413
# Epoch 50: saving model to model_epoch_50.keras
#
# Epoch 50: val_accuracy did not improve from 0.95931
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 182s 83ms/step - accuracy: 0.0277 - loss: 3.6414 - val_accuracy: 0.0287 - val_loss: 3.6361

# %% [markdown]
# Save model

# %%
# Create the DS_Models folder if it doesn't exist
model_folder = '/content/drive/MyDrive/DS_Models'
os.makedirs(model_folder, exist_ok=True)

# Define the model save path
model_save_path = os.path.join(model_folder, 'LLC_VGG16_1Block_unfrozen_v1.keras')

# Define the path to the model in Colab and the Google Drive save path
colab_model_path = '/content/LLC_VGG16_1Block_unfrozen_v1.keras'  # Adjust if it's located elsewhere in your Colab environment
model_save_path = os.path.join(model_folder, 'LLC_VGG16_1Block_unfrozen_v1.keras')

# Copy the model to Google Drive
# !cp {colab_model_path} {model_save_path}

# Confirm the model is saved in Google Drive
# !ls /content/drive/MyDrive/DS_Models/
# Out:
# LLC_VGG16_1Block_unfrozen_v1.keras

# %% [markdown]
# Load model

# %%
from tensorflow.keras.models import load_model

# Define the path to the model on Google Drive
model_load_path = '/content/drive/MyDrive/DS_Models/LLC_VGG16_1Block_unfrozen_v1.keras'

# Load the model
model_vgg16 = load_model(model_load_path)

# Verify the model is loaded
model_vgg16.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 8, 8, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 38)                  │          19,494 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 47,352,884 (180.64 MB)
#  Trainable params: 15,784,294 (60.21 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 31,568,590 (120.42 MB)

# %% [markdown]
# Plot metrics

# %%
history = model_vgg16.history

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue', marker='x')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange', marker='x')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss', color='blue', marker='x')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange', marker='x')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-70ad34a722de> in <cell line: 1>()
# ----> 1 history = model_vgg16.history
#       2
#       3 # Accuracy Plot
#       4 plt.subplot(1, 2, 1)
#       5 plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue', marker='x')
#
# AttributeError: 'Sequential' object has no attribute 'history'

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Prediction and validation VGG16

# %%
# Generate predictions for validation set
val_pred = model_vgg16.predict(validation_generator)
val_pred_classes = np.argmax(val_pred, axis=1)
true_classes = validation_generator.classes

# Classification report
class_report = classification_report(true_classes, val_pred_classes)
print("Classification Report:\n", class_report)
# Out:
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 27s 47ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.03      0.03      0.03       504
#            1       0.02      0.02      0.02       497
#            2       0.03      0.03      0.03       440
#            3       0.03      0.03      0.03       502
#            4       0.02      0.02      0.02       454
#            5       0.01      0.01      0.01       421
#            6       0.02      0.02      0.02       456
#            7       0.02      0.02      0.02       410
#            8       0.03      0.03      0.03       477
#            9       0.04      0.04      0.04       477
#           10       0.01      0.01      0.01       465
#           11       0.03      0.03      0.03       472
#           12       0.03      0.03      0.03       480
#           13       0.02      0.02      0.02       430
#           14       0.02      0.02      0.02       423
#           15       0.02      0.02      0.02       503
#           16       0.03      0.03      0.03       459
#           17       0.03      0.03      0.03       432
#           18       0.03      0.03      0.03       478
#           19       0.02      0.02      0.02       497
#           20       0.04      0.04      0.04       485
#           21       0.03      0.03      0.03       485
#           22       0.02      0.02      0.02       456
#           23       0.03      0.03      0.03       445
#           24       0.02      0.02      0.02       505
#           25       0.02      0.02      0.02       434
#           26       0.02      0.02      0.02       444
#           27       0.03      0.03      0.03       456
#           28       0.02      0.02      0.02       425
#           29       0.03      0.03      0.03       480
#           30       0.03      0.03      0.03       463
#           31       0.03      0.03      0.03       470
#           32       0.01      0.01      0.01       436
#           33       0.03      0.03      0.03       435
#           34       0.02      0.02      0.02       457
#           35       0.02      0.02      0.02       490
#           36       0.03      0.03      0.03       448
#           37       0.03      0.03      0.03       481
#
#     accuracy                           0.03     17572
#    macro avg       0.03      0.03      0.03     17572
# weighted avg       0.03      0.03      0.03     17572

# %%
# Step 1: Evaluate the model on the validation set
loss, accuracy = model_vgg16.evaluate(validation_generator)
# Out:
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 28s 48ms/step - accuracy: 0.9611 - loss: 0.1364

# %%
# Step 2: Print the accuracy
print(f'Validation loss: {loss:.2f}')
print(f'Validation accuracy: {accuracy:.2f}')
# Out:
# Validation loss: 0.15
# Validation accuracy: 0.96

# %% [markdown]
# Evaluate the test folder

# %%
# Define helper function to preprocess a single image
def preprocess_image(image_path, target_size):
    img = load_img(image_path, target_size=target_size)  # Load image and resize
    img_array = img_to_array(img) / 255.0               # Convert to array and rescale
    return img_array

# Load and preprocess all images from the test folder
def load_test_images(test_path, target_size):
    test_images = []
    filenames = []
    for file in os.listdir(test_path):
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):  # Supported file formats
            file_path = os.path.join(test_path, file)
            test_images.append(preprocess_image(file_path, target_size))
            filenames.append(file)  # Save filenames for reference
    return np.array(test_images), filenames

# Function to check if prediction is correct based on common words
def is_prediction_correct(file_name, predicted_label):
    # Extract meaningful words from file name (split camel case or concatenated words)
    file_name = re.sub(r'\.\w+$', '', file_name)  # Remove file extension
    file_words = set(word.lower() for word in re.findall(r'[A-Z][a-z]*|[a-z]+', file_name))  # Handle camel case and lowercase

    # Extract meaningful words from predicted label
    label_words = set(word.lower() for word in re.findall(r'[A-Za-z]+', predicted_label))  # Convert to lowercase

    # Check if all file words are in the label words
    is_subset = file_words.issubset(label_words)

    # Debugging output to verify
    #print(f"File Words: {file_words}, Label Words: {label_words}, Is Subset: {is_subset}")

    return is_subset

# Parameters
IMG_SIZE = (256, 256)  # Adjust to model's input size
test_path = test_path  # Define the test folder path

# Load and preprocess test images
test_images, filenames = load_test_images(test_path, target_size=IMG_SIZE)

# Make Predictions
predictions = model_vgg16.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Map predictions to class labels
class_labels = train_generator.class_indices
class_indices = {v: k for k, v in class_labels.items()}  # Reverse mapping of class indices
predicted_labels = [class_indices[idx] for idx in predicted_classes]

# Process and evaluate predictions
results = []

for file, pred, label in zip(filenames, predictions, predicted_labels):
    confidence = np.max(pred)  # Get the highest probability (confidence score)
    is_correct = is_prediction_correct(file, label)  # Check prediction correctness
    results.append({"True class": file, "prediction": label, "confidence": confidence, "Correct": int(is_correct)})
    print(f"True class: {file}, Prediction: {label}, Confidence: {confidence:.2f}, Correct: {is_correct}")

# Summary of results
correct_predictions = sum(result['Correct'] for result in results)
total_predictions = len(results)
accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
print(f"Total Predictions: {total_predictions}, Correct: {correct_predictions}, Accuracy: {accuracy:.2%}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step
# True class: TomatoYellowCurlVirus2.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00, Correct: True
# True class: TomatoYellowCurlVirus3.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00, Correct: True
# True class: TomatoEarlyBlight3.JPG, Prediction: Tomato___Early_blight, Confidence: 1.00, Correct: True
# True class: TomatoEarlyBlight1.JPG, Prediction: Tomato___Early_blight, Confidence: 1.00, Correct: True
# True class: AppleCedarRust3.JPG, Prediction: Peach___Bacterial_spot, Confidence: 0.92, Correct: False
# True class: TomatoEarlyBlight2.JPG, Prediction: Tomato___Late_blight, Confidence: 0.72, Correct: False
# True class: TomatoYellowCurlVirus6.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00, Correct: True
# True class: PotatoHealthy2.JPG, Prediction: Potato___healthy, Confidence: 1.00, Correct: True
# True class: AppleCedarRust2.JPG, Prediction: Apple___Cedar_apple_rust, Confidence: 0.98, Correct: True
# True class: PotatoEarlyBlight5.JPG, Prediction: Potato___Early_blight, Confidence: 1.00, Correct: True
# True class: TomatoHealthy2.JPG, Prediction: Tomato___healthy, Confidence: 1.00, Correct: True
# True class: AppleScab3.JPG, Prediction: Potato___Early_blight, Confidence: 0.84, Correct: False
# True class: CornCommonRust1.JPG, Prediction: Corn_(maize)___Common_rust_, Confidence: 1.00, Correct: True
# True class: TomatoEarlyBlight6.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 0.20, Correct: False
# True class: TomatoHealthy3.JPG, Prediction: Tomato___healthy, Confidence: 1.00, Correct: True
# True class: TomatoEarlyBlight5.JPG, Prediction: Tomato___Early_blight, Confidence: 1.00, Correct: True
# True class: PotatoEarlyBlight1.JPG, Prediction: Potato___Early_blight, Confidence: 1.00, Correct: True
# True class: TomatoYellowCurlVirus1.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00, Correct: True
# True class: AppleScab1.JPG, Prediction: Apple___Apple_scab, Confidence: 0.99, Correct: True
# True class: TomatoYellowCurlVirus4.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00, Correct: True
# True class: TomatoHealthy1.JPG, Prediction: Tomato___healthy, Confidence: 0.98, Correct: True
# True class: TomatoEarlyBlight4.JPG, Prediction: Tomato___Early_blight, Confidence: 0.98, Correct: True
# True class: CornCommonRust2.JPG, Prediction: Corn_(maize)___Common_rust_, Confidence: 1.00, Correct: True
# True class: CornCommonRust3.JPG, Prediction: Corn_(maize)___Common_rust_, Confidence: 1.00, Correct: True
# True class: AppleCedarRust1.JPG, Prediction: Apple___Cedar_apple_rust, Confidence: 1.00, Correct: True
# True class: PotatoEarlyBlight2.JPG, Prediction: Potato___Early_blight, Confidence: 1.00, Correct: True
# True class: PotatoEarlyBlight3.JPG, Prediction: Potato___Early_blight, Confidence: 1.00, Correct: True
# True class: TomatoYellowCurlVirus5.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00, Correct: True
# True class: PotatoHealthy1.JPG, Prediction: Potato___healthy, Confidence: 1.00, Correct: True
# True class: PotatoEarlyBlight4.JPG, Prediction: Potato___Early_blight, Confidence: 1.00, Correct: True
# True class: TomatoHealthy4.JPG, Prediction: Tomato___healthy, Confidence: 1.00, Correct: True
# True class: AppleCedarRust4.JPG, Prediction: Apple___Cedar_apple_rust, Confidence: 0.61, Correct: True
# True class: AppleScab2.JPG, Prediction: Apple___Apple_scab, Confidence: 1.00, Correct: True
# Total Predictions: 33, Correct: 29, Accuracy: 87.88%

# %%
# Define helper function to preprocess a single image
def preprocess_image(image_path, target_size):
    img = load_img(image_path, target_size=target_size)  # Load image and resize
    img_array = img_to_array(img) / 255.0               # Convert to array and rescale
    return img_array

# Load and preprocess all images from the test folder
def load_test_images(test_path, target_size):
    test_images = []
    filenames = []
    for file in os.listdir(test_path):
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):  # Supported file formats
            file_path = os.path.join(test_path, file)
            test_images.append(preprocess_image(file_path, target_size))
            filenames.append(file)  # Save filenames for reference
    return np.array(test_images), filenames

# Parameters
IMG_SIZE = (256, 256)  # Adjust to model's input size
test_path = test_path

# Load and preprocess test images
test_images, filenames = load_test_images(test_path, target_size=IMG_SIZE)

# Make Predictions
predictions = model_vgg16.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Map predictions to class labels
class_labels = train_generator.class_indices
class_indices = {v: k for k, v in class_labels.items()}  # Reverse mapping of class indices
predicted_labels = [class_indices[idx] for idx in predicted_classes]

# Print predictions with filenames
results = []

for file, pred, label in zip(filenames, predictions, predicted_labels):
    confidence = np.max(pred)  # Get the highest probability (confidence score)
    print(f"True class:{file}, Predictions:{label} (Confidence: {confidence:.2f})")

    # Pause and ask for feedback
    feedback = input("Is the prediction correct? (1 for Yes, 0 for No): ")
    if feedback == "1":
        results.append({"file": file, "prediction": label, "confidence": confidence, "Correct": "1"})
    else:
        results.append({"file": file, "prediction": label, "confidence": confidence, "Correct": "0"})
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True class:TomatoYellowCurlVirus2.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoYellowCurlVirus3.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight3.JPG, Predictions:Tomato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight1.JPG, Predictions:Tomato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleCedarRust3.JPG, Predictions:Peach___Bacterial_spot (Confidence: 0.92)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:TomatoEarlyBlight2.JPG, Predictions:Tomato___Late_blight (Confidence: 0.72)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:TomatoYellowCurlVirus6.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:PotatoHealthy2.JPG, Predictions:Potato___healthy (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleCedarRust2.JPG, Predictions:Apple___Cedar_apple_rust (Confidence: 0.98)
# Is the prediction correct? (1 for Yes, 0 for No):
# True class:PotatoEarlyBlight5.JPG, Predictions:Potato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoHealthy2.JPG, Predictions:Tomato___healthy (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleScab3.JPG, Predictions:Potato___Early_blight (Confidence: 0.84)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:CornCommonRust1.JPG, Predictions:Corn_(maize)___Common_rust_ (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight6.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 0.20)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:TomatoHealthy3.JPG, Predictions:Tomato___healthy (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight5.JPG, Predictions:Tomato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:PotatoEarlyBlight1.JPG, Predictions:Potato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoYellowCurlVirus1.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:AppleScab1.JPG, Predictions:Apple___Apple_scab (Confidence: 0.99)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoYellowCurlVirus4.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoHealthy1.JPG, Predictions:Tomato___healthy (Confidence: 0.98)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight4.JPG, Predictions:Tomato___Early_blight (Confidence: 0.98)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:CornCommonRust2.JPG, Predictions:Corn_(maize)___Common_rust_ (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:CornCommonRust3.JPG, Predictions:Corn_(maize)___Common_rust_ (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleCedarRust1.JPG, Predictions:Apple___Cedar_apple_rust (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:PotatoEarlyBlight2.JPG, Predictions:Potato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:PotatoEarlyBlight3.JPG, Predictions:Potato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoYellowCurlVirus5.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:PotatoHealthy1.JPG, Predictions:Potato___healthy (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:PotatoEarlyBlight4.JPG, Predictions:Potato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoHealthy4.JPG, Predictions:Tomato___healthy (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleCedarRust4.JPG, Predictions:Apple___Cedar_apple_rust (Confidence: 0.61)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleScab2.JPG, Predictions:Apple___Apple_scab (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1

# %% [markdown]
# Create DataFrame and save as CSV in google drive

# %%
# Create a DataFrame from the results
df_results = pd.DataFrame(results)

# Print the DataFrame
print("\nSummary of Predictions and Feedback:")
display(df_results)

# Save DataFrame to CSV
output_csv_path = f"{save_dir}/{Model_name}_predictions.csv"  # Specify the output file path
df_results.to_csv(output_csv_path, index=False)

print(f"Predictions have been saved to {output_csv_path}")
# Out:
# Summary of Predictions and Feedback:
#                           file                              prediction  \
# 0   TomatoYellowCurlVirus2.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 1   TomatoYellowCurlVirus3.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 2       TomatoEarlyBlight3.JPG                   Tomato___Early_blight
# 3       TomatoEarlyBlight1.JPG                   Tomato___Early_blight
# 4          AppleCedarRust3.JPG                  Peach___Bacterial_spot
# 5       TomatoEarlyBlight2.JPG                    Tomato___Late_blight
# 6   TomatoYellowCurlVirus6.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 7           PotatoHealthy2.JPG                        Potato___healthy
# 8          AppleCedarRust2.JPG                Apple___Cedar_apple_rust
# 9       PotatoEarlyBlight5.JPG                   Potato___Early_blight
# 10          TomatoHealthy2.JPG                        Tomato___healthy
# 11              AppleScab3.JPG                   Potato___Early_blight
# 12         CornCommonRust1.JPG             Corn_(maize)___Common_rust_
# 13      TomatoEarlyBlight6.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 14          TomatoHealthy3.JPG                        Tomato___healthy
# 15      TomatoEarlyBlight5.JPG                   Tomato___Early_blight
# 16      PotatoEarlyBlight1.JPG                   Potato___Early_blight
# 17  TomatoYellowCurlVirus1.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 18              AppleScab1.JPG                      Apple___Apple_scab
# 19  TomatoYellowCurlVirus4.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 20          TomatoHealthy1.JPG                        Tomato___healthy
# 21      TomatoEarlyBlight4.JPG                   Tomato___Early_blight
# 22         CornCommonRust2.JPG             Corn_(maize)___Common_rust_
# 23         CornCommonRust3.JPG             Corn_(maize)___Common_rust_
# 24         AppleCedarRust1.JPG                Apple___Cedar_apple_rust
# 25      PotatoEarlyBlight2.JPG                   Potato___Early_blight
# 26      PotatoEarlyBlight3.JPG                   Potato___Early_blight
# 27  TomatoYellowCurlVirus5.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 28          PotatoHealthy1.JPG                        Potato___healthy
# 29      PotatoEarlyBlight4.JPG                   Potato___Early_blight
# 30          TomatoHealthy4.JPG                        Tomato___healthy
# 31         AppleCedarRust4.JPG                Apple___Cedar_apple_rust
# 32              AppleScab2.JPG                      Apple___Apple_scab
#
#     confidence Correct
# 0     1.000000       1
# 1     0.999830       1
# 2     0.999221       1
# 3     0.999994       1
# 4     0.922439       0
# 5     0.717354       0
# 6     1.000000       1
# 7     0.999971       1
# 8     0.982735       0
# 9     1.000000       1
# 10    0.995175       1
# 11    0.838922       0
# 12    1.000000       1
# 13    0.195090       0
# 14    1.000000       1
# 15    0.999689       1
# 16    1.000000       1
# 17    0.999159       0
# 18    0.986451       1
# 19    1.000000       1
# 20    0.978493       1
# 21    0.978074       1
# 22    1.000000       1
# 23    0.999975       1
# 24    1.000000       1
# 25    1.000000       1
# 26    0.998994       1
# 27    0.999790       1
# 28    0.999852       1
# 29    1.000000       1
# 30    0.999997       1
# 31    0.610005       1
# 32    0.998429       1
# Predictions have been saved to /content/drive/MyDrive/DS_models/LLC_VGG16_1Block_unfrozen_v1_predictions.csv

# %% [markdown]
# prediction accuracy

# %%
df_results["Correct"].value_counts(normalize=True)
# Out:
# Correct
# 1    0.818182
# 0    0.181818
# Name: proportion, dtype: float64
