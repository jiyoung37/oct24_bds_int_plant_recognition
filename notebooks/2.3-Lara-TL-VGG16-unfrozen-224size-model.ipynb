# %% [markdown]
# # Import files, libraries, define path and initialize lists

# %%
# !pip install kagglehub
from google.colab import files

import kagglehub

# Download the latest version of the dataset
path = kagglehub.dataset_download("vipoooool/new-plant-diseases-dataset")

print("Path to dataset files:", path)
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.11/dist-packages (0.3.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from kagglehub) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2024.12.14)
# Downloading from https://www.kaggle.com/api/v1/datasets/download/vipoooool/new-plant-diseases-dataset?dataset_version_number=2...
# 100%|██████████| 2.70G/2.70G [00:12<00:00, 234MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
from PIL import Image
import glob
import os
import shutil
import re
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.applications import EfficientNetV2L
from tensorflow.keras.applications import VGG16
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# Mounted at /content/drive

# %%
# Define the dataset path
root_folder = "/root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2"

data_dir = os.path.join(root_folder, 'new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/')

test_path = os.path.join(root_folder, 'test/test')
train_path = os.path.join(data_dir, 'train')
valid_path = os.path.join(data_dir, 'valid')

# %%
# Initialize lists
image_paths = []
species_labels = []
disease_labels = []
dataset_split = []

# Function to process a dataset directory
def process_directory(base_path, split_name):
    for class_folder in os.listdir(base_path):
        class_folder_path = os.path.join(base_path, class_folder)
        if os.path.isdir(class_folder_path):
            species, disease = class_folder.split('___')
            for image_name in os.listdir(class_folder_path):
                image_paths.append(os.path.join(class_folder_path, image_name))
                species_labels.append(species)
                disease_labels.append(disease)
                dataset_split.append(split_name)

# Process train and valid
process_directory(train_path, 'train')
process_directory(valid_path, 'valid')

# Create DataFrame
df = pd.DataFrame({
    'image_path': image_paths,
    'species': species_labels,
    'disease': disease_labels,
    'split': dataset_split
})

# %% [markdown]
# # Model Training

# %%
import keras
keras.backend.clear_session()

#Define model name
Model_name = 'LLC_VGG16_unfrozen_224size_v1'

# %%
# Define the image generators for the training and validation set
batch_size = 32
num_classes = 38
img_size = (224, 224)

train_datagen = ImageDataGenerator(rescale=1./255)

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
    valid_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)
# Out:
# Found 70295 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.

# %%
# Import the VGG16 model as a baseline
base_model = VGG16(weights="imagenet", include_top=False, input_shape=(224, 224, 3))

# Unfreeze the base model layers
for layer in base_model.layers:
    layer.trainable = True

# Add custom layers for classification
model_vgg16 = Sequential()
model_vgg16.add(base_model)
model_vgg16.add(GlobalAveragePooling2D())
model_vgg16.add(Dense(1024, activation="relu"))
model_vgg16.add(Dropout(rate=0.2))
model_vgg16.add(Dense(512, activation="relu"))
model_vgg16.add(Dropout(rate=0.2))
model_vgg16.add(Dense(num_classes, activation="softmax"))

# Compile the model
optimizer = Adam(learning_rate = 0.001)
model_vgg16.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# Define callbacks
epoch_checkpoint = ModelCheckpoint(
    'model_epoch_{epoch:02d}.keras',  # Filename to save the model, it will save with the epoch number
    save_weights_only=False,       # Save the entire model (including architecture, optimizer, and weights)
    save_freq='epoch',             # Save the model after every epoch
    verbose=1                      # Print a message when saving the model
)
best_model = ModelCheckpoint(
    f"{Model_name}.keras",
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

callbacks = [
    epoch_checkpoint,
    best_model
]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Training the model
model_vgg16.fit(
    train_generator,
    epochs = 50,
    validation_data = validation_generator,
    callbacks = callbacks
    )
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1750 - loss: 2.8999
# Epoch 1: saving model to model_epoch_01.keras
#
# Epoch 1: val_accuracy improved from -inf to 0.63573, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 197s 80ms/step - accuracy: 0.1751 - loss: 2.8996 - val_accuracy: 0.6357 - val_loss: 1.0928
# Epoch 2/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6650 - loss: 1.0164
# Epoch 2: saving model to model_epoch_02.keras
#
# Epoch 2: val_accuracy improved from 0.63573 to 0.75751, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 147s 67ms/step - accuracy: 0.6650 - loss: 1.0163 - val_accuracy: 0.7575 - val_loss: 0.7313
# Epoch 3/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8139 - loss: 0.5596
# Epoch 3: saving model to model_epoch_03.keras
#
# Epoch 3: val_accuracy improved from 0.75751 to 0.85767, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 147s 67ms/step - accuracy: 0.8139 - loss: 0.5596 - val_accuracy: 0.8577 - val_loss: 0.4275
# Epoch 4/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8672 - loss: 0.4074
# Epoch 4: saving model to model_epoch_04.keras
#
# Epoch 4: val_accuracy improved from 0.85767 to 0.88806, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.8672 - loss: 0.4074 - val_accuracy: 0.8881 - val_loss: 0.3397
# Epoch 5/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8958 - loss: 0.3216
# Epoch 5: saving model to model_epoch_05.keras
#
# Epoch 5: val_accuracy improved from 0.88806 to 0.91020, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.8958 - loss: 0.3216 - val_accuracy: 0.9102 - val_loss: 0.2754
# Epoch 6/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9075 - loss: 0.2824
# Epoch 6: saving model to model_epoch_06.keras
#
# Epoch 6: val_accuracy improved from 0.91020 to 0.92482, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9075 - loss: 0.2824 - val_accuracy: 0.9248 - val_loss: 0.2267
# Epoch 7/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9201 - loss: 0.2418
# Epoch 7: saving model to model_epoch_07.keras
#
# Epoch 7: val_accuracy improved from 0.92482 to 0.92562, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 147s 67ms/step - accuracy: 0.9201 - loss: 0.2418 - val_accuracy: 0.9256 - val_loss: 0.2224
# Epoch 8/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9291 - loss: 0.2241
# Epoch 8: saving model to model_epoch_08.keras
#
# Epoch 8: val_accuracy improved from 0.92562 to 0.92568, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 147s 67ms/step - accuracy: 0.9291 - loss: 0.2241 - val_accuracy: 0.9257 - val_loss: 0.2257
# Epoch 9/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9363 - loss: 0.1979
# Epoch 9: saving model to model_epoch_09.keras
#
# Epoch 9: val_accuracy improved from 0.92568 to 0.93188, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9363 - loss: 0.1979 - val_accuracy: 0.9319 - val_loss: 0.2090
# Epoch 10/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9336 - loss: 0.2009
# Epoch 10: saving model to model_epoch_10.keras
#
# Epoch 10: val_accuracy did not improve from 0.93188
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9336 - loss: 0.2009 - val_accuracy: 0.9290 - val_loss: 0.2224
# Epoch 11/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9391 - loss: 0.1890
# Epoch 11: saving model to model_epoch_11.keras
#
# Epoch 11: val_accuracy improved from 0.93188 to 0.93638, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9391 - loss: 0.1890 - val_accuracy: 0.9364 - val_loss: 0.1941
# Epoch 12/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9435 - loss: 0.1730
# Epoch 12: saving model to model_epoch_12.keras
#
# Epoch 12: val_accuracy did not improve from 0.93638
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9435 - loss: 0.1730 - val_accuracy: 0.8854 - val_loss: 0.3583
# Epoch 13/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9419 - loss: 0.1823
# Epoch 13: saving model to model_epoch_13.keras
#
# Epoch 13: val_accuracy improved from 0.93638 to 0.93968, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 67ms/step - accuracy: 0.9419 - loss: 0.1823 - val_accuracy: 0.9397 - val_loss: 0.1857
# Epoch 14/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9429 - loss: 0.1772
# Epoch 14: saving model to model_epoch_14.keras
#
# Epoch 14: val_accuracy did not improve from 0.93968
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9429 - loss: 0.1772 - val_accuracy: 0.9224 - val_loss: 0.2410
# Epoch 15/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9512 - loss: 0.1583
# Epoch 15: saving model to model_epoch_15.keras
#
# Epoch 15: val_accuracy improved from 0.93968 to 0.94292, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9512 - loss: 0.1583 - val_accuracy: 0.9429 - val_loss: 0.1828
# Epoch 16/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9495 - loss: 0.1573
# Epoch 16: saving model to model_epoch_16.keras
#
# Epoch 16: val_accuracy improved from 0.94292 to 0.94702, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 147s 67ms/step - accuracy: 0.9495 - loss: 0.1573 - val_accuracy: 0.9470 - val_loss: 0.1631
# Epoch 17/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9481 - loss: 0.1636
# Epoch 17: saving model to model_epoch_17.keras
#
# Epoch 17: val_accuracy did not improve from 0.94702
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9481 - loss: 0.1636 - val_accuracy: 0.9414 - val_loss: 0.1852
# Epoch 18/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9445 - loss: 0.1791
# Epoch 18: saving model to model_epoch_18.keras
#
# Epoch 18: val_accuracy did not improve from 0.94702
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9445 - loss: 0.1791 - val_accuracy: 0.9257 - val_loss: 0.2561
# Epoch 19/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9483 - loss: 0.1629
# Epoch 19: saving model to model_epoch_19.keras
#
# Epoch 19: val_accuracy did not improve from 0.94702
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 145s 66ms/step - accuracy: 0.9483 - loss: 0.1629 - val_accuracy: 0.9423 - val_loss: 0.1826
# Epoch 20/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9518 - loss: 0.1488
# Epoch 20: saving model to model_epoch_20.keras
#
# Epoch 20: val_accuracy did not improve from 0.94702
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 145s 66ms/step - accuracy: 0.9518 - loss: 0.1488 - val_accuracy: 0.9206 - val_loss: 0.2537
# Epoch 21/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9527 - loss: 0.1500
# Epoch 21: saving model to model_epoch_21.keras
#
# Epoch 21: val_accuracy did not improve from 0.94702
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9527 - loss: 0.1500 - val_accuracy: 0.9427 - val_loss: 0.1883
# Epoch 22/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9492 - loss: 0.1638
# Epoch 22: saving model to model_epoch_22.keras
#
# Epoch 22: val_accuracy improved from 0.94702 to 0.94861, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9492 - loss: 0.1638 - val_accuracy: 0.9486 - val_loss: 0.1647
# Epoch 23/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9405 - loss: 0.1952
# Epoch 23: saving model to model_epoch_23.keras
#
# Epoch 23: val_accuracy improved from 0.94861 to 0.95521, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 145s 66ms/step - accuracy: 0.9405 - loss: 0.1952 - val_accuracy: 0.9552 - val_loss: 0.1429
# Epoch 24/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9576 - loss: 0.1334
# Epoch 24: saving model to model_epoch_24.keras
#
# Epoch 24: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 144s 66ms/step - accuracy: 0.9576 - loss: 0.1334 - val_accuracy: 0.9488 - val_loss: 0.1672
# Epoch 25/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9541 - loss: 0.1471
# Epoch 25: saving model to model_epoch_25.keras
#
# Epoch 25: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9541 - loss: 0.1471 - val_accuracy: 0.9357 - val_loss: 0.2137
# Epoch 26/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9510 - loss: 0.1575
# Epoch 26: saving model to model_epoch_26.keras
#
# Epoch 26: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9510 - loss: 0.1575 - val_accuracy: 0.9437 - val_loss: 0.1846
# Epoch 27/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9577 - loss: 0.1316
# Epoch 27: saving model to model_epoch_27.keras
#
# Epoch 27: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9577 - loss: 0.1317 - val_accuracy: 0.9283 - val_loss: 0.2386
# Epoch 28/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9493 - loss: 0.1667
# Epoch 28: saving model to model_epoch_28.keras
#
# Epoch 28: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9493 - loss: 0.1667 - val_accuracy: 0.9379 - val_loss: 0.1985
# Epoch 29/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9473 - loss: 0.1740
# Epoch 29: saving model to model_epoch_29.keras
#
# Epoch 29: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9473 - loss: 0.1740 - val_accuracy: 0.9441 - val_loss: 0.1886
# Epoch 30/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9605 - loss: 0.1281
# Epoch 30: saving model to model_epoch_30.keras
#
# Epoch 30: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9605 - loss: 0.1281 - val_accuracy: 0.9461 - val_loss: 0.1738
# Epoch 31/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9389 - loss: 0.2046
# Epoch 31: saving model to model_epoch_31.keras
#
# Epoch 31: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9389 - loss: 0.2046 - val_accuracy: 0.9521 - val_loss: 0.1655
# Epoch 32/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9493 - loss: 0.1652
# Epoch 32: saving model to model_epoch_32.keras
#
# Epoch 32: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9493 - loss: 0.1652 - val_accuracy: 0.9256 - val_loss: 0.2487
# Epoch 33/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9582 - loss: 0.1345
# Epoch 33: saving model to model_epoch_33.keras
#
# Epoch 33: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9582 - loss: 0.1345 - val_accuracy: 0.9488 - val_loss: 0.1712
# Epoch 34/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9546 - loss: 0.1546
# Epoch 34: saving model to model_epoch_34.keras
#
# Epoch 34: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9546 - loss: 0.1546 - val_accuracy: 0.9356 - val_loss: 0.2217
# Epoch 35/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9580 - loss: 0.1343
# Epoch 35: saving model to model_epoch_35.keras
#
# Epoch 35: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9580 - loss: 0.1343 - val_accuracy: 0.9462 - val_loss: 0.1830
# Epoch 36/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9543 - loss: 0.1521
# Epoch 36: saving model to model_epoch_36.keras
#
# Epoch 36: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9543 - loss: 0.1521 - val_accuracy: 0.9466 - val_loss: 0.1800
# Epoch 37/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9477 - loss: 0.1808
# Epoch 37: saving model to model_epoch_37.keras
#
# Epoch 37: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 145s 66ms/step - accuracy: 0.9477 - loss: 0.1808 - val_accuracy: 0.9498 - val_loss: 0.1657
# Epoch 38/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9565 - loss: 0.1468
# Epoch 38: saving model to model_epoch_38.keras
#
# Epoch 38: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 145s 66ms/step - accuracy: 0.9565 - loss: 0.1468 - val_accuracy: 0.9449 - val_loss: 0.1896
# Epoch 39/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9573 - loss: 0.1436
# Epoch 39: saving model to model_epoch_39.keras
#
# Epoch 39: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 145s 66ms/step - accuracy: 0.9573 - loss: 0.1436 - val_accuracy: 0.9437 - val_loss: 0.1923
# Epoch 40/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9603 - loss: 0.1309
# Epoch 40: saving model to model_epoch_40.keras
#
# Epoch 40: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9603 - loss: 0.1309 - val_accuracy: 0.9354 - val_loss: 0.2121
# Epoch 41/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9546 - loss: 0.1495
# Epoch 41: saving model to model_epoch_41.keras
#
# Epoch 41: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 145s 66ms/step - accuracy: 0.9546 - loss: 0.1495 - val_accuracy: 0.9310 - val_loss: 0.2372
# Epoch 42/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9609 - loss: 0.1320
# Epoch 42: saving model to model_epoch_42.keras
#
# Epoch 42: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 147s 67ms/step - accuracy: 0.9609 - loss: 0.1320 - val_accuracy: 0.9221 - val_loss: 0.2684
# Epoch 43/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9572 - loss: 0.1423
# Epoch 43: saving model to model_epoch_43.keras
#
# Epoch 43: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9572 - loss: 0.1423 - val_accuracy: 0.9515 - val_loss: 0.1641
# Epoch 44/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9620 - loss: 0.1225
# Epoch 44: saving model to model_epoch_44.keras
#
# Epoch 44: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 147s 67ms/step - accuracy: 0.9620 - loss: 0.1225 - val_accuracy: 0.9550 - val_loss: 0.1540
# Epoch 45/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9565 - loss: 0.1465
# Epoch 45: saving model to model_epoch_45.keras
#
# Epoch 45: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 147s 67ms/step - accuracy: 0.9565 - loss: 0.1465 - val_accuracy: 0.9451 - val_loss: 0.1867
# Epoch 46/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9593 - loss: 0.1334
# Epoch 46: saving model to model_epoch_46.keras
#
# Epoch 46: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 145s 66ms/step - accuracy: 0.9593 - loss: 0.1334 - val_accuracy: 0.9503 - val_loss: 0.1580
# Epoch 47/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9686 - loss: 0.1051
# Epoch 47: saving model to model_epoch_47.keras
#
# Epoch 47: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9686 - loss: 0.1051 - val_accuracy: 0.9508 - val_loss: 0.1701
# Epoch 48/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9578 - loss: 0.1483
# Epoch 48: saving model to model_epoch_48.keras
#
# Epoch 48: val_accuracy did not improve from 0.95521
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 145s 66ms/step - accuracy: 0.9578 - loss: 0.1483 - val_accuracy: 0.9392 - val_loss: 0.2189
# Epoch 49/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9152 - loss: 0.4371
# Epoch 49: saving model to model_epoch_49.keras
#
# Epoch 49: val_accuracy improved from 0.95521 to 0.95783, saving model to LLC_VGG16_unfrozen_224size_v1.keras
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9152 - loss: 0.4370 - val_accuracy: 0.9578 - val_loss: 0.1436
# Epoch 50/50
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9717 - loss: 0.0984
# Epoch 50: saving model to model_epoch_50.keras
#
# Epoch 50: val_accuracy did not improve from 0.95783
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 146s 66ms/step - accuracy: 0.9717 - loss: 0.0984 - val_accuracy: 0.9358 - val_loss: 0.2169

# %% [markdown]
# Save model

# %%
# Create the DS_Models folder if it doesn't exist
model_folder = '/content/drive/MyDrive/DS_models'
os.makedirs(model_folder, exist_ok=True)

# Define the model save path
model_save_path = os.path.join(model_folder, 'LLC_VGG16_unfrozen_224size_v1.keras')

# Define the path to the model in Colab and the Google Drive save path
colab_model_path = '/content/LLC_VGG16_unfrozen_224size_v1.keras'  # Adjust if it's located elsewhere in your Colab environment
model_save_path = os.path.join(model_folder, 'LLC_VGG16_unfrozen_224size_v1.keras')

# Copy the model to Google Drive
# !cp {colab_model_path} {model_save_path}

# Confirm the model is saved in Google Drive
# !ls /content/drive/MyDrive/DS_models/

save_dir = model_folder
# Out:
# best_model_epoch_07.keras		  LLC_VGG16_1Block_unfrozen_v1_predictions.csv
# best_VGG16_model_epoch_7.keras		  LLC_VGG16_unfrozen_224size_v1.keras
# best_VGG16_unfrozen_model_epoch_6.keras   LLC_VGG16_unfrozenlowerLR_v1.keras
# LLC_MobileNetV2_1Block_unfrozen_v1.keras  LLC_VGG16_unfrozen_v1.keras
# LLC_MobileNetV2_unfrozen_v1.keras	  LLC_VGG16_unfrozen_v1_predictions.csv
# LLC_VGG16_1Block_unfrozen_v1.keras	  model_epoch_02.keras
# LLC_VGG16_1Block_unfrozen_v1_old.keras

# %% [markdown]
# Plot Metrics

# %%
#Plot metrics history
history = model_vgg16.history

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue', marker='x')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange', marker='x')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss', color='blue', marker='x')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange', marker='x')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-70ad34a722de> in <cell line: 0>()
#       3 # Accuracy Plot
#       4 plt.subplot(1, 2, 1)
# ----> 5 plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue', marker='x')
#       6 plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange', marker='x')
#       7 plt.title('Training and Validation Accuracy')
#
# KeyError: 'accuracy'

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Prediction and validation VGG16

# %%
# Generate predictions for validation set
val_pred = model_vgg16.predict(validation_generator)
val_pred_classes = np.argmax(val_pred, axis=1)
true_classes = validation_generator.classes

# Classification report
class_report = classification_report(true_classes, val_pred_classes)
print("Classification Report:\n", class_report)
# Out:
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 25s 43ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.02      0.02      0.02       504
#            1       0.03      0.03      0.03       497
#            2       0.02      0.02      0.02       440
#            3       0.04      0.04      0.04       502
#            4       0.02      0.02      0.02       454
#            5       0.02      0.02      0.02       421
#            6       0.02      0.02      0.02       456
#            7       0.03      0.03      0.03       410
#            8       0.01      0.01      0.01       477
#            9       0.02      0.02      0.02       477
#           10       0.02      0.02      0.02       465
#           11       0.04      0.04      0.04       472
#           12       0.02      0.02      0.02       480
#           13       0.01      0.01      0.01       430
#           14       0.02      0.02      0.02       423
#           15       0.04      0.04      0.04       503
#           16       0.03      0.03      0.03       459
#           17       0.01      0.01      0.01       432
#           18       0.02      0.02      0.02       478
#           19       0.02      0.02      0.02       497
#           20       0.03      0.03      0.03       485
#           21       0.03      0.03      0.03       485
#           22       0.03      0.03      0.03       456
#           23       0.03      0.04      0.03       445
#           24       0.02      0.02      0.02       505
#           25       0.02      0.02      0.02       434
#           26       0.03      0.03      0.03       444
#           27       0.02      0.02      0.02       456
#           28       0.02      0.03      0.03       425
#           29       0.04      0.04      0.04       480
#           30       0.03      0.03      0.03       463
#           31       0.03      0.03      0.03       470
#           32       0.01      0.01      0.01       436
#           33       0.02      0.02      0.02       435
#           34       0.03      0.03      0.03       457
#           35       0.02      0.02      0.02       490
#           36       0.03      0.03      0.03       448
#           37       0.04      0.04      0.04       481
#
#     accuracy                           0.03     17572
#    macro avg       0.03      0.03      0.03     17572
# weighted avg       0.03      0.03      0.03     17572

# %%
# Step 1: Evaluate the model on the validation set
loss, accuracy = model_vgg16.evaluate(validation_generator)
# Out:
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 23s 42ms/step - accuracy: 0.9354 - loss: 0.2155

# %%
# Step 2: Print the accuracy
print(f'Validation loss: {loss:.2f}')
print(f'Validation accuracy: {accuracy:.2f}')
# Out:
# Validation loss: 0.22
# Validation accuracy: 0.94

# %% [markdown]
# Evaluate the test folder

# %%
# Define helper function to preprocess a single image
def preprocess_image(image_path, target_size):
    img = load_img(image_path, target_size=target_size)  # Load image and resize
    img_array = img_to_array(img) / 255.0               # Convert to array and rescale
    return img_array

# Load and preprocess all images from the test folder
def load_test_images(test_path, target_size):
    test_images = []
    filenames = []
    for file in os.listdir(test_path):
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):  # Supported file formats
            file_path = os.path.join(test_path, file)
            test_images.append(preprocess_image(file_path, target_size))
            filenames.append(file)  # Save filenames for reference
    return np.array(test_images), filenames

# Function to check if prediction is correct based on common words
def is_prediction_correct(file_name, predicted_label):
    # Extract meaningful words from file name (split camel case or concatenated words)
    file_name = re.sub(r'\.\w+$', '', file_name)  # Remove file extension
    file_words = set(word.lower() for word in re.findall(r'[A-Z][a-z]*|[a-z]+', file_name))  # Handle camel case and lowercase

    # Extract meaningful words from predicted label
    label_words = set(word.lower() for word in re.findall(r'[A-Za-z]+', predicted_label))  # Convert to lowercase

    # Check if all file words are in the label words
    is_subset = file_words.issubset(label_words)

    # Debugging output to verify
    #print(f"File Words: {file_words}, Label Words: {label_words}, Is Subset: {is_subset}")

    return is_subset

# Parameters
IMG_SIZE = (224, 224)  # Adjust to model's input size
test_path = test_path  # Define the test folder path

# Load and preprocess test images
test_images, filenames = load_test_images(test_path, target_size=IMG_SIZE)

# Make Predictions
predictions = model_vgg16.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Map predictions to class labels
class_labels = train_generator.class_indices
class_indices = {v: k for k, v in class_labels.items()}  # Reverse mapping of class indices
predicted_labels = [class_indices[idx] for idx in predicted_classes]

# Process and evaluate predictions
results = []

for file, pred, label in zip(filenames, predictions, predicted_labels):
    confidence = np.max(pred)  # Get the highest probability (confidence score)
    is_correct = is_prediction_correct(file, label)  # Check prediction correctness
    results.append({"True class": file, "prediction": label, "confidence": confidence, "Correct": int(is_correct)})
    print(f"True class: {file}, Prediction: {label}, Confidence: {confidence:.2f}, Correct: {is_correct}")

# Summary of results
correct_predictions = sum(result['Correct'] for result in results)
total_predictions = len(results)
accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
print(f"Total Predictions: {total_predictions}, Correct: {correct_predictions}, Accuracy: {accuracy:.2%}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step
# True class: PotatoEarlyBlight2.JPG, Prediction: Potato___Early_blight, Confidence: 1.00, Correct: True
# True class: AppleScab1.JPG, Prediction: Apple___Apple_scab, Confidence: 0.97, Correct: True
# True class: TomatoHealthy3.JPG, Prediction: Tomato___healthy, Confidence: 0.99, Correct: True
# True class: PotatoEarlyBlight1.JPG, Prediction: Potato___Early_blight, Confidence: 1.00, Correct: True
# True class: AppleCedarRust3.JPG, Prediction: Apple___Cedar_apple_rust, Confidence: 1.00, Correct: True
# True class: AppleScab3.JPG, Prediction: Apple___Apple_scab, Confidence: 1.00, Correct: True
# True class: AppleScab2.JPG, Prediction: Apple___Apple_scab, Confidence: 1.00, Correct: True
# True class: TomatoYellowCurlVirus3.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 0.55, Correct: True
# True class: CornCommonRust1.JPG, Prediction: Corn_(maize)___Common_rust_, Confidence: 1.00, Correct: True
# True class: TomatoHealthy1.JPG, Prediction: Tomato___healthy, Confidence: 1.00, Correct: True
# True class: AppleCedarRust1.JPG, Prediction: Apple___Cedar_apple_rust, Confidence: 1.00, Correct: True
# True class: TomatoHealthy4.JPG, Prediction: Tomato___Target_Spot, Confidence: 0.79, Correct: False
# True class: CornCommonRust2.JPG, Prediction: Corn_(maize)___Common_rust_, Confidence: 1.00, Correct: True
# True class: TomatoEarlyBlight2.JPG, Prediction: Tomato___Early_blight, Confidence: 0.56, Correct: True
# True class: PotatoEarlyBlight5.JPG, Prediction: Potato___Early_blight, Confidence: 0.72, Correct: True
# True class: TomatoEarlyBlight1.JPG, Prediction: Tomato___Late_blight, Confidence: 0.52, Correct: False
# True class: TomatoYellowCurlVirus4.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00, Correct: True
# True class: TomatoYellowCurlVirus6.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00, Correct: True
# True class: TomatoEarlyBlight3.JPG, Prediction: Pepper,_bell___Bacterial_spot, Confidence: 0.29, Correct: False
# True class: AppleCedarRust4.JPG, Prediction: Apple___Cedar_apple_rust, Confidence: 0.96, Correct: True
# True class: TomatoEarlyBlight5.JPG, Prediction: Tomato___Septoria_leaf_spot, Confidence: 0.82, Correct: False
# True class: PotatoEarlyBlight4.JPG, Prediction: Potato___Early_blight, Confidence: 0.97, Correct: True
# True class: TomatoYellowCurlVirus5.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 1.00, Correct: True
# True class: TomatoHealthy2.JPG, Prediction: Apple___healthy, Confidence: 0.65, Correct: False
# True class: TomatoYellowCurlVirus1.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 0.89, Correct: True
# True class: AppleCedarRust2.JPG, Prediction: Apple___Cedar_apple_rust, Confidence: 1.00, Correct: True
# True class: PotatoEarlyBlight3.JPG, Prediction: Potato___Early_blight, Confidence: 0.95, Correct: True
# True class: TomatoYellowCurlVirus2.JPG, Prediction: Tomato___Tomato_Yellow_Leaf_Curl_Virus, Confidence: 0.69, Correct: True
# True class: PotatoHealthy2.JPG, Prediction: Potato___healthy, Confidence: 0.99, Correct: True
# True class: TomatoEarlyBlight6.JPG, Prediction: Potato___Late_blight, Confidence: 0.36, Correct: False
# True class: PotatoHealthy1.JPG, Prediction: Potato___healthy, Confidence: 0.65, Correct: True
# True class: TomatoEarlyBlight4.JPG, Prediction: Tomato___Early_blight, Confidence: 1.00, Correct: True
# True class: CornCommonRust3.JPG, Prediction: Corn_(maize)___Common_rust_, Confidence: 1.00, Correct: True
# Total Predictions: 33, Correct: 27, Accuracy: 81.82%

# %%
# Define helper function to preprocess a single image
def preprocess_image(image_path, target_size):
    img = load_img(image_path, target_size=target_size)  # Load image and resize
    img_array = img_to_array(img) / 255.0               # Convert to array and rescale
    return img_array

# Load and preprocess all images from the test folder
def load_test_images(test_path, target_size):
    test_images = []
    filenames = []
    for file in os.listdir(test_path):
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):  # Supported file formats
            file_path = os.path.join(test_path, file)
            test_images.append(preprocess_image(file_path, target_size))
            filenames.append(file)  # Save filenames for reference
    return np.array(test_images), filenames

# Parameters
IMG_SIZE = (224, 224)  # Adjust to model's input size
test_path = test_path

# Load and preprocess test images
test_images, filenames = load_test_images(test_path, target_size=IMG_SIZE)

# Make Predictions
predictions = model_vgg16.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Map predictions to class labels
class_labels = train_generator.class_indices
class_indices = {v: k for k, v in class_labels.items()}  # Reverse mapping of class indices
predicted_labels = [class_indices[idx] for idx in predicted_classes]

# Print predictions with filenames
results = []

for file, pred, label in zip(filenames, predictions, predicted_labels):
    confidence = np.max(pred)  # Get the highest probability (confidence score)
    print(f"True class:{file}, Predictions:{label} (Confidence: {confidence:.2f})")

    # Pause and ask for feedback
    feedback = input("Is the prediction correct? (1 for Yes, 0 for No): ")
    if feedback == "1":
        results.append({"file": file, "prediction": label, "confidence": confidence, "Correct": "1"})
    else:
        results.append({"file": file, "prediction": label, "confidence": confidence, "Correct": "0"})
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# True class:PotatoEarlyBlight2.JPG, Predictions:Potato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No):
# True class:AppleScab1.JPG, Predictions:Apple___Apple_scab (Confidence: 0.97)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoHealthy3.JPG, Predictions:Tomato___healthy (Confidence: 0.99)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:PotatoEarlyBlight1.JPG, Predictions:Potato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleCedarRust3.JPG, Predictions:Apple___Cedar_apple_rust (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleScab3.JPG, Predictions:Apple___Apple_scab (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleScab2.JPG, Predictions:Apple___Apple_scab (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoYellowCurlVirus3.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 0.55)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:CornCommonRust1.JPG, Predictions:Corn_(maize)___Common_rust_ (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoHealthy1.JPG, Predictions:Tomato___healthy (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleCedarRust1.JPG, Predictions:Apple___Cedar_apple_rust (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoHealthy4.JPG, Predictions:Tomato___Target_Spot (Confidence: 0.79)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:CornCommonRust2.JPG, Predictions:Corn_(maize)___Common_rust_ (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight2.JPG, Predictions:Tomato___Early_blight (Confidence: 0.56)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:PotatoEarlyBlight5.JPG, Predictions:Potato___Early_blight (Confidence: 0.72)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight1.JPG, Predictions:Tomato___Late_blight (Confidence: 0.52)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:TomatoYellowCurlVirus4.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoYellowCurlVirus6.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight3.JPG, Predictions:Pepper,_bell___Bacterial_spot (Confidence: 0.29)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:AppleCedarRust4.JPG, Predictions:Apple___Cedar_apple_rust (Confidence: 0.96)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight5.JPG, Predictions:Tomato___Septoria_leaf_spot (Confidence: 0.82)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:PotatoEarlyBlight4.JPG, Predictions:Potato___Early_blight (Confidence: 0.97)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoYellowCurlVirus5.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoHealthy2.JPG, Predictions:Apple___healthy (Confidence: 0.65)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:TomatoYellowCurlVirus1.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 0.89)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:AppleCedarRust2.JPG, Predictions:Apple___Cedar_apple_rust (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:PotatoEarlyBlight3.JPG, Predictions:Potato___Early_blight (Confidence: 0.95)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoYellowCurlVirus2.JPG, Predictions:Tomato___Tomato_Yellow_Leaf_Curl_Virus (Confidence: 0.69)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:PotatoHealthy2.JPG, Predictions:Potato___healthy (Confidence: 0.99)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight6.JPG, Predictions:Potato___Late_blight (Confidence: 0.36)
# Is the prediction correct? (1 for Yes, 0 for No): 0
# True class:PotatoHealthy1.JPG, Predictions:Potato___healthy (Confidence: 0.65)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:TomatoEarlyBlight4.JPG, Predictions:Tomato___Early_blight (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1
# True class:CornCommonRust3.JPG, Predictions:Corn_(maize)___Common_rust_ (Confidence: 1.00)
# Is the prediction correct? (1 for Yes, 0 for No): 1

# %% [markdown]
# Create DataFrame and save as CSV in google drive

# %%
# Create a DataFrame from the results
df_results = pd.DataFrame(results)

# Print the DataFrame
print("\nSummary of Predictions and Feedback:")
display(df_results)

# Save DataFrame to CSV
output_csv_path = f"{save_dir}/{Model_name}_predictions.csv"  # Specify the output file path
df_results.to_csv(output_csv_path, index=False)

print(f"Predictions have been saved to {output_csv_path}")
# Out:
# Summary of Predictions and Feedback:
#                           file                              prediction  \
# 0       PotatoEarlyBlight2.JPG                   Potato___Early_blight
# 1               AppleScab1.JPG                      Apple___Apple_scab
# 2           TomatoHealthy3.JPG                        Tomato___healthy
# 3       PotatoEarlyBlight1.JPG                   Potato___Early_blight
# 4          AppleCedarRust3.JPG                Apple___Cedar_apple_rust
# 5               AppleScab3.JPG                      Apple___Apple_scab
# 6               AppleScab2.JPG                      Apple___Apple_scab
# 7   TomatoYellowCurlVirus3.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 8          CornCommonRust1.JPG             Corn_(maize)___Common_rust_
# 9           TomatoHealthy1.JPG                        Tomato___healthy
# 10         AppleCedarRust1.JPG                Apple___Cedar_apple_rust
# 11          TomatoHealthy4.JPG                    Tomato___Target_Spot
# 12         CornCommonRust2.JPG             Corn_(maize)___Common_rust_
# 13      TomatoEarlyBlight2.JPG                   Tomato___Early_blight
# 14      PotatoEarlyBlight5.JPG                   Potato___Early_blight
# 15      TomatoEarlyBlight1.JPG                    Tomato___Late_blight
# 16  TomatoYellowCurlVirus4.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 17  TomatoYellowCurlVirus6.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 18      TomatoEarlyBlight3.JPG           Pepper,_bell___Bacterial_spot
# 19         AppleCedarRust4.JPG                Apple___Cedar_apple_rust
# 20      TomatoEarlyBlight5.JPG             Tomato___Septoria_leaf_spot
# 21      PotatoEarlyBlight4.JPG                   Potato___Early_blight
# 22  TomatoYellowCurlVirus5.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 23          TomatoHealthy2.JPG                         Apple___healthy
# 24  TomatoYellowCurlVirus1.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 25         AppleCedarRust2.JPG                Apple___Cedar_apple_rust
# 26      PotatoEarlyBlight3.JPG                   Potato___Early_blight
# 27  TomatoYellowCurlVirus2.JPG  Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 28          PotatoHealthy2.JPG                        Potato___healthy
# 29      TomatoEarlyBlight6.JPG                    Potato___Late_blight
# 30          PotatoHealthy1.JPG                        Potato___healthy
# 31      TomatoEarlyBlight4.JPG                   Tomato___Early_blight
# 32         CornCommonRust3.JPG             Corn_(maize)___Common_rust_
#
#     confidence Correct
# 0     1.000000       0
# 1     0.974593       1
# 2     0.992473       1
# 3     0.999999       1
# 4     0.999724       1
# 5     0.999794       1
# 6     0.999963       1
# 7     0.550672       1
# 8     1.000000       1
# 9     0.999998       1
# 10    0.999945       1
# 11    0.790818       0
# 12    1.000000       1
# 13    0.556509       1
# 14    0.719188       1
# 15    0.521973       0
# 16    1.000000       1
# 17    0.999877       1
# 18    0.293695       0
# 19    0.957674       1
# 20    0.817869       0
# 21    0.971102       1
# 22    0.999941       1
# 23    0.654514       0
# 24    0.892588       1
# 25    0.999395       1
# 26    0.948074       1
# 27    0.685362       1
# 28    0.993912       1
# 29    0.359553       0
# 30    0.651941       1
# 31    0.999616       1
# 32    1.000000       1
# Predictions have been saved to /content/drive/MyDrive/DS_models/LLC_VGG16_unfrozen_224size_v1_predictions.csv

# %% [markdown]
# prediction accuracy

# %%
df_results["Correct"].value_counts(normalize=True)
# Out:
# Correct
# 0    0.909091
# 1    0.090909
# Name: proportion, dtype: float64
